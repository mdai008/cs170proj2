# %%
from featureSearch import *
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('CS170_Spring_2023_Small_data__35.txt', sep=' ', header = None, engine = 'python', skipinitialspace = True)

xAxis = data.iloc[:,4]
yAxis = data.iloc[:,6]
labels = data.iloc[:,0]

# xAxis = np.array(xAxis)
# yAxis = np.array(yAxis)
# labels = np.array(labels)

# scaler = StandardScaler()
# scaler.fit(xAxis)
# xAxis = scaler.transform(xAxis)

# scaler = StandardScaler()
# scaler.fit(yAxis)
# yAxis = scaler.transform(yAxis)

xAxis = np.array(xAxis)
yAxis = np.array(yAxis)
labels = np.array(labels)

# df = pd.DataFrame([labels,xAxis,yAxis],["Label","Feature 3","Feature 5"])

df = pd.DataFrame(labels, columns=['Label'])
df["Feature 3"] = xAxis
df["Feature 5"] = yAxis

# display(df.head())

sb.scatterplot(x="Feature 3", y="Feature 5", data=df, hue="Label")
# Out:
# <AxesSubplot: xlabel='Feature 3', ylabel='Feature 5'>

# %%
data = pd.read_csv('CS170_Spring_2023_Large_data__35.txt', sep=' ', header = None, engine = 'python', skipinitialspace = True)

xAxis = data.iloc[:,5]
yAxis = data.iloc[:,37]
labels = data.iloc[:,0]

xAxis = np.array(xAxis)
yAxis = np.array(yAxis)
labels = np.array(labels)

# df = pd.DataFrame([labels,xAxis,yAxis],["Label","Feature 3","Feature 5"])

df = pd.DataFrame(labels, columns=['Label'])
df["Feature 4"] = xAxis
df["Feature 36"] = yAxis

# display(df.head())

sb.scatterplot(x="Feature 4", y="Feature 36", data=df, hue="Label")
# Out:
# <AxesSubplot: xlabel='Feature 4', ylabel='Feature 36'>
